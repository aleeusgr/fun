# %%
"""
TO_IMPLEMENT:
search
height as class method
"""
class Node:
    'binary search tree consists of nodes:'
    def __init__(self, info):  
        self.info = info  
        self.left = None  
        self.right = None 
        self.level = None 

    def __str__(self):
        return str(self.info) 
'it is used to store/sort data'
'take a number, if it is less than the node, it goes left, if it is greater, then right'
class BinarySearchTree:
    def __init__(self):                 
        self.root = None                          #tree is created empty
    
#     def __str__(self):
        
#         return str(self.root.info)
    
    def preorder(self,start,traversal):
        "start is tree.node, traversal is str"
        if start:
            traversal+=str(start.level)+'/'+str(start.info)+'-'
            traversal=self.preorder(start.left,traversal)
            traversal=self.preorder(start.right,traversal)
        return traversal
    def search(self,root,val):
        'function to search val, returns path'
        
        return 

    
    def create(self, val):  
        if self.root == None:                     #if root is empty, set it to be Node with current value
            self.root = Node(val)
            self.root.level=0
        else:                                     #current is where we're looking at
            current = self.root
            
            while True:
                if val < current.info:            
                    if current.left:              #exists
                        current = current.left    
                    else:
                        current.left = Node(val)
                        current.left.level=current.level+1
                        break
                
                elif val > current.info:
                    if current.right:
                        current = current.right
                    else:
                        current.right = Node(val)
                        current.right.level=current.level+1
                        break
                
                else:
                    break
                    
def height(root):
    'root is type node'
    if root is None: # base case, reached lowest leaf
        return -1
    left_h = height(root.left) 
    right_h = height(root.right)
    return 1 + max(left_h,right_h)

# %%
tree = BinarySearchTree()
arr = list(map(int,str.split('4 2 3 1 7 6')))

for i in arr:
    tree.create(i)
    
"""
     4
   /   \
  2     7
 / \   /
1   3 6 

"""

def lca(root, v1, v2):
    'lowest common ancestor'
    

v=[1,7]
ans = lca(tree.root, v[0], v[1])

# print(tree.preorder(tree.root,''))
# print(height(tree.root))
# print(ans)
val = 7
print(tree.search(val))
