# %%
buy_price = 100
markup = int(input("enter markup:"))
operating_cost = int(input('op_cost:'))
print("sell_price=",(1+markup/100)*buy_price)
tax_a = (1+markup/100)*buy_price*0.06
tax_b = ((markup/100)*buy_price - operating_cost)*0.15
print(tax_a+operating_cost,tax_b)
# Out:
# enter markup: 67
# op_cost: 0
# sell_price= 167.0
# 10.02 10.049999999999999

# %%
buy_price = 100
#markup = int(input("enter markup:"))
operating_cost = float(input('op_cost:'))
print("sell_price=",(1+markup/100)*buy_price)
for markup in range(30,100):
    tax_a = (1+markup/100)*buy_price*0.06
    tax_b = ((markup/100)*buy_price - operating_cost)*0.15
    if tax_b>tax_a: 
        print("---------------")
    print(tax_a)
    print(tax_b)
    print(markup)
    print()
# Out:
# op_cost: 3
# sell_price= 199.0
# 7.8
# 4.05
# 30
#
# 7.859999999999999
# 4.2
# 31
#
# 7.92
# 4.35
# 32
#
# 7.9799999999999995
# 4.5
# 33
#
# 8.04
# 4.6499999999999995
# 34
#
# 8.1
# 4.8
# 35
#
# 8.16
# 4.95
# 36
#
# 8.219999999999999
# 5.1
# 37
#
# 8.28
# 5.25
# 38
#
# 8.34
# 5.3999999999999995
# 39
#
# 8.4
# 5.55
# 40
#
# 8.459999999999999
# 5.7
# 41
#
# 8.52
# 5.85
# 42
#
# 8.58
# 6.0
# 43
#
# 8.64
# 6.1499999999999995
# 44
#
# 8.7
# 6.3
# 45
#
# 8.76
# 6.45
# 46
#
# 8.82
# 6.6
# 47
#
# 8.879999999999999
# 6.75
# 48
#
# 8.94
# 6.8999999999999995
# 49
#
# 9.0
# 7.05
# 50
#
# 9.06
# 7.199999999999999
# 51
#
# 9.12
# 7.35
# 52
#
# 9.18
# 7.5
# 53
#
# 9.24
# 7.6499999999999995
# 54
#
# 9.299999999999999
# 7.800000000000001
# 55
#
# 9.36
# 7.950000000000001
# 56
#
# 9.419999999999998
# 8.099999999999998
# 57
#
# 9.48
# 8.249999999999998
# 58
#
# 9.54
# 8.4
# 59
#
# 9.6
# 8.549999999999999
# 60
#
# 9.66
# 8.7
# 61
#
# 9.719999999999999
# 8.85
# 62
#
# 9.78
# 9.0
# 63
#
# 9.84
# 9.15
# ...
